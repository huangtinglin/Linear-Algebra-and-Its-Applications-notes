# %% [markdown]
# # 特征值和特征向量
# $\quad$$A$为$n\times n$矩阵，$\mathbf{x}$为非零向量，若存在数$\lambda$使$A\mathbf{x}=\lambda \mathbf{x}$有非平凡解$\mathbf{x}$，则称$\lambda$为$A$的**特征值**（可以为零），$\mathbf{x}$称为对应于$\lambda$的**特征向量**（非零）。
# $\quad$若$\lambda$为矩阵$A$的特征值，那么方程
# $$(A-\lambda I)\mathbf{x}=\mathbf{0}$$
# 中所有解的集合（$A-\lambda I$的零空间）称为$A$的对应于$\lambda$的**特征空间**。
# $\quad$直观地，设$A=\left[\begin{array}{}1 & 6\\5 & 2\end{array} \right],\mathbf{u}=\left[\begin{array}{}6\\-5\end{array} \right],\mathbf{v}=\left[\begin{array}{}3\\-2\end{array} \right]$，计算有：
# $$A\mathbf{u}=\left[\begin{array}{}-24\\20\end{array} \right]=-4\left[\begin{array}{}6\\-5\end{array} \right]=4\mathbf{u},A\mathbf{v}=\left[\begin{array}{}-9\\11\end{array} \right]\neq \lambda\left[\begin{array}{}3\\-2\end{array} \right]$$
# 因此$\mathbf{u}$是特征值-4对应的特征向量，但$\mathbf{v}$不是$A$的特征向量。
# <img src="_image/10_1.PNG" width="250" height="200" />
# $\quad$我们考虑特征值为零的情况，当矩阵$A$有零特征值时，方程
# $$A\mathbf{x}=\mathbf{0}\mathbf{x}$$
# 有非平凡解，说明矩阵$A$不可逆，因此可以下一个结论：**0是矩阵$A$的特征值当且仅当$A$不可逆**。
# ## 1.特征方程求特征根
# $\quad$给定一个$n\times n$的矩阵$A$，如何求特征值和对应的特征向量？
# $\quad$特征值$\lambda$需满足方程$A\mathbf{x}=\lambda \mathbf{x}$中的$\mathbf{x}$有解存在，也即方程
# $$(A-\lambda I)\mathbf{x}=\mathbf{0}$$
# 有非零解存在，根据可逆矩阵定理，若矩阵$A-\lambda I$线性无关，则方程只有零解，因此要使方程有解，矩阵$A-\lambda I$不可逆，也即行列式$|A-\lambda I|$等于0。
# $\quad$引出定理：数$\lambda$是$n\times n$矩阵$A$的特征值的充要条件为$\lambda$是**特征方程**$|A-\lambda I|=0$的根。
# $\quad$举例如下：
# <img src="_image/10_2.PNG" width="450" height="400" />
# 可以发现**特征方程**$|A-\lambda I|=0$是关于$\lambda$的的多项式，也称之为$\lambda$的特征多项式。
# $\quad$还可以应用[QR分解]()、[奇异值分解]()来求矩阵的特征值。在实际编程中，更多地是用奇异值分解。
# ## 2.应用
# $\quad$下面通过一个例子来说明特征值和特征向量的作用：
# <img src="_image/10_3.PNG" width="450" height="400" />
# ## 3.几何意义
# $\quad$矩阵是一次[线性变换](《线性代数及其应用》笔记08.矩阵的几何解释-线性变换.ipynb)，那么特征向量就是在线性变换前后、只做了伸缩未改变方向的向量，而特征值就是伸缩的比例，当特征值为负表明特征向量被反向拉伸。
